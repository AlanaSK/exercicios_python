# %%
for n in range(1,11):
    print(n)

# %%
for n in range(0,21):
    if n % 2 == 0:
        print(n)

# %%
num = int(input('Digite um numero:'))

for n in range(1, 11):
    print(f'{num} x {n} = {num * n}')

# %%
soma = 0

for n in range(1, 101):
    soma += n

print(soma)

# %%
numero = int(input('Digite um numero:'))
qtd_pares = 0

for n in range(1, numero + 1):
    if n % 2 == 0:
        qtd_pares += 1

print('digite:', numero)
print('resultado:', qtd_pares)

# %%
numero = int(input('Digite um numero:'))
fatorial = 1

for n in range(1, numero + 1):
    fatorial *= n 

print('digite:', numero)
print('resultado:', fatorial)

# %%
from statistics import mean

numeros = []

while True:
    num = int(input('digite um numero:'))
    if num == 0:
        tamanho = len(numeros)
        media = mean(numeros)

        print(f"a média é: {media}")
        break
    else:
        numeros.append(num)

# %%
import random

rand_num = random.randint(1, 100)
num = int(input('Digite um número:'))

while True:
    if num > rand_num:
        print('Menor')
        num = int(input('Digite um número:'))
    elif num < rand_num:
        print('Maior')
        num = int(input('Digite um número:'))
    else:
        print('Acertou')
        break
print(rand_num)

# %%
num_lado = int(input('Digite um numero:'))

for n in range(num_lado):
    print(num_lado * '*')
